# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path = "student-mat.csv"
data = pd.read_csv(path, delimiter=';')

# %%
selected_columns = ["freetime", "studytime"]
selected_data = data[selected_columns]
correlations = selected_data.corr()

# %%
plt.figure(figsize=(5, 5))  
sns.heatmap(correlations, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Correlation between Freetime and Studytime")
plt.show()

# %%
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
data.info
# Out:
# <bound method DataFrame.info of     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
dfn=data[['freetime','studytime']]

# %%
dfn.head
# Out:
# <bound method NDFrame.head of      freetime  studytime
# 0           3          2
# 1           3          2
# 2           3          2
# 3           2          3
# 4           3          2
# ..        ...        ...
# 390         5          2
# 391         4          1
# 392         5          1
# 393         4          1
# 394         2          1
#
# [395 rows x 2 columns]>

# %%
x=dfn['freetime']
y=dfn['studytime']

# %%
sns.lineplot(x, dashes=True)
plt.show()

# %%
sns.lineplot(y,dashes=True)
plt.show()

# %%
from scipy.stats import norm

# %%
corelation=dfn.corr()

# %%
print(corelation)
# Out:
#            freetime  studytime
# freetime   1.000000  -0.143198
# studytime -0.143198   1.000000

# %%
sns.heatmap(corelation,cmap ="YlGnBu")
plt.show()

# %%
covar=dfn.cov()

# %%
print(covar)
# Out:
#            freetime  studytime
# freetime   0.997725  -0.120041
# studytime -0.120041   0.704324

# %%
sns.heatmap(covar,cmap='YlGnBu')
plt.show()
