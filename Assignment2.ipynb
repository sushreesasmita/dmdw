# %%
import pandas as pd
import numpy as nu
import matplotlib as mb
dataset = pd.read_csv("Iris.csv")

# %%
dataset.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
column = dataset['SepalLengthCm']

# %%
mean_with_library = column.mean()
median_with_library = column.median()
mode_with_library = column.mode().values[0]

# %%
variance_with_library = column.var()
standard_deviation_with_library = column.std()

# %%
mean_without_library = sum(column) / len(column)

sorted_column = sorted(column)
n = len(sorted_column)
if n % 2 == 0:
    mid1 = sorted_column[n // 2]
    mid2 = sorted_column[n // 2 - 1]
    median_without_library = (mid1 + mid2) / 2
else:
    median_without_library = sorted_column[n // 2]

counts = {}
for value in column:
    if value in counts:
        counts[value] += 1
    else:
        counts[value] = 1

max_count = max(counts.values())
modes_without_library = [value for value, count in counts.items() if count == max_count]
mode_without_library = modes_without_library[0]

# %%
squared_diffs = [(value - mean_without_library) ** 2 for value in column]
variance_without_library = sum(squared_diffs) / len(column)
standard_deviation_without_library = variance_without_library ** 0.5

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
df = pd.read_csv('Iris.csv')
df.head
# Out:
# <ipython-input-12-1a0c2489e3d8>:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')
# <bound method NDFrame.head of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# ...

# %%
sb.lmplot(x='SepalLengthCm', y='SepalWidthCm', data=df,hue='PetalLengthCm',fit_reg=True)
plt.show()

# %%
sb.lmplot(x='SepalLengthCm', y='SepalWidthCm', data=df,hue='PetalLengthCm',fit_reg=True)
plt.show()

# %%
sb.boxplot(df['SepalLengthCm'],notch=True,orient='v',color='Green',width=0.74)
plt.show()

# %%
sb.boxplot(df['SepalWidthCm'],notch=True,orient='v',color='red',width=0.74)
plt.show()

# %%
sb.boxplot(df['PetalLengthCm'],notch=True,orient='v',color='Gold',width=0.74)
plt.show()

# %%
plt.hist(df['SepalLengthCm'],bins=20,ec='black',color='red')
plt.show()

# %%
plt.hist(df['SepalWidthCm'],bins=20,ec='black',color='red')
plt.show()

# %%
plt.hist(df['PetalLengthCm'],bins=20,ec='black',color='red')
plt.show()

# %%
sb.jointplot(df['SepalLengthCm'],kind='hex',color='red')
plt.show()
name=df['SepalLengthCm']
SepalLengthCm=name[:10]
SepalWidthCm=df['SepalWidthCm']
SepalLengthCm=SepalLengthCm[:10]

# %%
sb.jointplot(df['SepalLengthCm'],kind='hex',color='red')
plt.show()
name=df['SepalLengthCm']
SepalLengthCm=name[:10]
SepalWidthCm=df['SepalWidthCm']
SepalLengthCm=SepalLengthCm[:10]

# %%
sb.jointplot(df['SepalWidthCm'],kind='hex',color='red')
plt.show()
name=df['SepalWidthCm']
SepalWidthCm=name[:10]
SepalLengthCm=df['SepalLengthCm']
SepalWidthCm=SepalWidthCm[:10]

# %%
name = ['PetalWidthCm', 'SepalWidthCm', 'PetalLengthCm', 'SepalLengthCm']
attack = [10, 20, 30, 40]

plt.barh(name, value, linewidth=0.7, edgecolor='red', color=['red', 'yellow', 'blue', 'cyan'])
plt.show()

# %%
name = ['SepalWidthCm', 'SepalLengthCm', 'PetalLengthCm', 'PetalWidthCm']
attack = [10, 20, 30, 40]

plt.barh(name, attack, linewidth=0.7, edgecolor='red', color=['red', 'yellow', 'blue', 'cyan'])
plt.title('Horizontal Bar Plot')
plt.show()

# %%
stage = [20, 30, 50]
labels = ['1.3', '1.4', '1.5']

plt.pie(stage, labels=labels, shadow=True, startangle=90, autopct='%1.2f%%')
plt.title("PetalLengthCm Data")
plt.axis('equal')

plt.show()

# %%
stage = [20, 30, 50]
labels = ['1.3', '1.4', '1.5']

plt.pie(stage, labels=labels, shadow=True, startangle=90, autopct='%1.2f%%')
plt.title("PetalLengthCm Data")
plt.axis('equal')

plt.show()

# %%
plt.plot(df['PetalLengthCm'],color='green')
plt.show()

# %%
plt.plot(df['SepalLengthCm'],color='green')
plt.show()

# %%
plt.plot(df['SepalWidthCm'],color='green')
plt.show()

# %%
plt.plot(df['PetalWidthCm'],color='green')
plt.show()

# %%
plt.scatter(df['SepalLengthCm'],df['SepalWidthCm'],color=['Gold'])
plt.xlabel('SepalLengthCm')
plt.ylabel('SepalWidthCm')
plt.title("SepalWidth vs SepalLength")
plt.show()

# %%
df.describe()
df.info( )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
